# %% [markdown]
# # Kutubxonalarni o'rnatish va birinchi dataset bilan ishlash

# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 11.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 12.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 8.3 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 7.9 MB/s eta 0:00:00ta 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 3.1 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 6.8 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 11.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.5/271.5 kB 5.7 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 11.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 3.4 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 12.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 6.0 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 11.5 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbs

# %%
# Pandas
# Datani vs code ga olish
df=pd.read_csv("topuniversities.csv")

# %%
df.head()
df.tail()
# Out:
#      Rank  Ordinal Rank                           University Name  \
# 295   296           296  National Chinyi University of Technology
# 296   297           296               Sungshin Women's University
# 297   298           298              Northwest University (China)
# 298   299           299                 Ocean University of China
# 299   300           300          Huazhong Agricultural University
#
#      Overall Score           City      Country  Citations per Paper  \
# 295           29.5  Taichung City       Taiwan                 25.8
# 296           29.5          Seoul  South Korea                  9.1
# 297           29.2          Xi'an        China                 64.5
# 298           29.1        Qingdao        China                 48.1
# 299           29.0          Wuhan        China                 91.5
#
#      Papers per Faculty  Academic Reputation  Faculty Student Ratio  \
# 295                15.9                 31.9                   12.9
# ...

# %%
# dataset haqida ma'lumot olish
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           300 non-null    int64
#  1   Ordinal Rank                   300 non-null    int64
#  2   University Name                300 non-null    object
#  3   Overall Score                  300 non-null    float64
#  4   City                           300 non-null    object
#  5   Country                        300 non-null    object
#  6   Citations per Paper            300 non-null    float64
#  7   Papers per Faculty             300 non-null    float64
#  8   Academic Reputation            300 non-null    float64
#  9   Faculty Student Ratio          300 non-null    float64
#  10  Staff with PhD                 294 non-null    float64
#  11  International Research Center  300 non-null    float64
# ...

# %%
# datasetni matematik tahlili ya'ni feature larni mean max min std qiymatlari
df.describe()
# Out:
#              Rank  Ordinal Rank  Overall Score  Citations per Paper  \
# count  300.000000    300.000000     300.000000           300.000000
# mean   150.500000    150.133333      52.057667            44.869667
# std     86.746758     86.556739      19.123336            34.088756
# min      1.000000      1.000000      29.000000             1.000000
# 25%     75.750000     75.750000      35.850000            11.075000
# 50%    150.500000    150.500000      46.250000            39.050000
# 75%    225.250000    225.250000      62.725000            76.150000
# max    300.000000    300.000000     100.000000           100.000000
#
#        Papers per Faculty  Academic Reputation  Faculty Student Ratio  \
# count          300.000000           300.000000             300.000000
# mean            41.288667            51.648000              50.976333
# std             29.994062            26.305925              31.338651
# min              1.200000             8.800000               2.600000
# ...

# %%
# null qiymatlar bor y'qligini tekshirish
df.isnull().sum()
# Out:
# Rank                              0
# Ordinal Rank                      0
# University Name                   0
# Overall Score                     0
# City                              0
# Country                           0
# Citations per Paper               0
# Papers per Faculty                0
# Academic Reputation               0
# Faculty Student Ratio             0
# Staff with PhD                    6
# International Research Center     0
# International Students            4
# Outbound Exchange                 0
# Inbound Exchange                  0
# International Faculty            17
# Employer Reputation               0
# dtype: int64

# %%
# null bor ustunlarni o'rtacha (mean) qiymatlar bilan to'ldirish
df['Staff with PhD'].fillna(df['Staff with PhD'].mean,inplace=True)
#df['International Students'].fillna(df['International Students'].mean,inplace=True)
#df['International Faculty '].fillna(df['International Faculty '].mean,inplace=True)

# %%
df['International Students'].fillna(df['International Students'].mean,inplace=True)

# %%
df['International Faculty'].fillna(df['International Faculty'].mean,inplace=True)
# Out:
# /var/folders/kx/n6bh82zd3w5_blhwkxh6d2440000gn/T/ipykernel_2709/1914578156.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<bound method Series.mean of 0       83.2
# 1      100.0
# 2      100.0
# 3      100.0
# 4       98.9
#        ...
# 295      5.1
# 296      7.7
# 297     10.6
# 298      8.5
# 299     11.7
# Name: International Faculty, Length: 300, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['International Faculty'].fillna(df['International Faculty'].mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank                             0
# Ordinal Rank                     0
# University Name                  0
# Overall Score                    0
# City                             0
# Country                          0
# Citations per Paper              0
# Papers per Faculty               0
# Academic Reputation              0
# Faculty Student Ratio            0
# Staff with PhD                   0
# International Research Center    0
# International Students           0
# Outbound Exchange                0
# Inbound Exchange                 0
# International Faculty            0
# Employer Reputation              0
# dtype: int64
